# %%
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk
import os

def login():
    u=un.get()
    c=pw.get()

    if u=="Parvat" and c=="1234":
        root=Toplevel(screen)
        root.title("Bill")
        root.geometry("1280x720+150+80")
        root.configure(bg="#d7dae2")
        root.resizeable(False,False)
    elif u=="" and c=="":
        messagebox.showerror("Invalid","Please enter username and password")
    elif u=="":
        messagebox.showerror("Invalid","Please enter username")
    elif c=="":
        messagebox.showerror("Invalid","Please enter password")
    elif u!="Parvat" and c!="1234":
        messagebox.showerror("Invalid","Invalid username and password")
    elif u!="Parvat":
        messagebox.showerror("Invalid","Invalid username")
    elif c!="1234":
        messagebox.showerror("Invalid","Invalid password") 
        
def main_screen():
    global screen
    global un
    global pw

    screen=Tk()
    screen.geometry("1280x720+150+80")
    screen.configure(bg="#d7dae2")
   
    img = Image.open("p1.png")
    i_i = ImageTk.PhotoImage(img)
    screen.iconphoto(False,i_i)
    screen.title("Login System")

    lt=Label(text="Login System",font=("arial",50,'bold'),fg="black",bg="#d7dae2")
    lt.pack(pady=50)

    bc=Frame(screen,bg="black",width=800,height=400)
    bc.pack(pady=20)

    mf=Frame(bc,bg="#d7dae2",width=800,height=400)
    mf.pack(padx=20,pady=20)
    
    Label(mf,text="Username",font=("arial",30,'bold'),bg="#d7dae2").place(x=100,y=50)
    Label(mf,text="Password",font=("arial",30,'bold'),bg="#d7dae2").place(x=100,y=150)
    un=StringVar()
    pw=StringVar()

    eu=Entry(mf,textvariable=un,width=12,bd=2,font=("arial",30))
    eu.place(x=400,y=50)
    ep=Entry(mf,textvariable=pw,width=12,bd=2,font=("arial",30),show="*")
    ep.place(x=400,y=150)

    def reset():
        eu.delete(0,END)
        ep.delete(0,END)
        
    Button(mf,text="Login",height="2",width=23,bg="#ed3833",fg="white",bd=0,command=login).place(x=100,y=250)
    Button(mf,text="Reset",height="2",width=23,bg="#1089ff",fg="white",bd=0,command=reset).place(x=300,y=250)
    Button(mf,text="Exit",height="2",width=23,bg="#00bd56",fg="white",bd=0,command=screen.destroy).place(x=500,y=250)
    
    
    screen.mainloop()
main_screen()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\tkinter\__init__.py", line 1968, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_708\1362707002.py", line 15, in login
#     root.resizeable(False,False)
#     ^^^^^^^^^^^^^^^
# AttributeError: 'Toplevel' object has no attribute 'resizeable'. Did you mean: 'resizable'?

# %%
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk
from datetime import datetime
import os

def open_diary():
    # New window for writing daily diary
    diary_window = Toplevel(screen)
    diary_window.title("Daily Diary")
    diary_window.geometry("1280x720+150+70")
    diary_window.configure(bg="#d7dae2")
    diary_window.resizable(False, False)

    diary_label = Label(diary_window, text="Write Your Daily Diary", font=("arial", 30, 'bold'), bg="#d7dae2")
    diary_label.pack(pady=20)

    diary_text = Text(diary_window, font=("arial", 20), width=80, height=15)
    diary_text.pack(pady=20)

    def save_diary():
        diary_content = diary_text.get("1.0", END).strip()
        if diary_content:
            current_time = datetime.now().strftime("%d-%m-%Y %H:%M:%S")
            entry = f"Entry Date and Time: {current_time}\n\n{diary_content}\n\n{'-'*40}\n\n"
            
            with open("diary.txt", "a") as file:
                file.write(entry)
            
            # Make the file read-only
            os.chmod("diary.txt", 0o444)
            
            messagebox.showinfo("Saved", "Your diary entry has been saved.")
            diary_text.delete("1.0", END)
        else:
            messagebox.showwarning("Empty", "Diary entry is empty.")
    Button(diary_window, text="Save Diary", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=save_diary).place(x=590, y=620)
    

def login():
    u = un.get()
    c = pw.get()

    if u == "Parvat" and c == "1234":        
        open_diary()
    elif u == "" and c == "":
        messagebox.showerror("Invalid", "Please enter username and password")
    elif u == "":
        messagebox.showerror("Invalid", "Please enter username")
    elif c == "":
        messagebox.showerror("Invalid", "Please enter password")
    elif u != "Parvat" and c != "1234":
        messagebox.showerror("Invalid", "Invalid username and password")
    elif u != "Parvat":
        messagebox.showerror("Invalid", "Invalid username")
    elif c != "1234":
        messagebox.showerror("Invalid", "Invalid password")

def main_screen():
    global screen
    global un
    global pw

    screen = Tk()
    screen.geometry("1280x720+150+80")
    screen.configure(bg="#d7dae2")

    img = Image.open("p1.png")
    i_i = ImageTk.PhotoImage(img)
    screen.iconphoto(False, i_i)
    screen.title("Login System")

    lt = Label(text="Login System", font=("arial", 50, 'bold'), fg="black", bg="#d7dae2")
    lt.pack(pady=50)

    bc = Frame(screen, bg="black", width=800, height=400)
    bc.pack(pady=20)

    mf = Frame(bc, bg="#d7dae2", width=800, height=400)
    mf.pack(padx=20, pady=20)

    Label(mf, text="Username", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=50)
    Label(mf, text="Password", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=150)
    un = StringVar()
    pw = StringVar()

    eu = Entry(mf, textvariable=un, width=12, bd=2, font=("arial", 30))
    eu.place(x=400, y=50)
    ep = Entry(mf, textvariable=pw, width=12, bd=2, font=("arial", 30), show="*")
    ep.place(x=400, y=150)

    def reset():
        eu.delete(0, END)
        ep.delete(0, END)

    Button(mf, text="Login", height="2", width=23, bg="#ed3833", fg="white", bd=0, command=login).place(x=100, y=250)
    Button(mf, text="Reset", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=reset).place(x=300, y=250)
    Button(mf, text="Exit", height="2", width=23, bg="#00bd56", fg="white", bd=0, command=screen.destroy).place(x=500, y=250)

    screen.mainloop()

main_screen()

# %%
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk
from datetime import datetime
import os
from cryptography.fernet import Fernet

# Generate a key for encryption
# Save the key securely for decryption later
key = Fernet.generate_key()
cipher_suite = Fernet(key)

def open_diary():
    # New window for writing daily diary
    diary_window = Toplevel(screen)
    diary_window.title("Daily Diary")
    diary_window.geometry("1280x720+150+70")
    diary_window.configure(bg="#d7dae2")
    diary_window.resizable(False, False)

    diary_label = Label(diary_window, text="Write Your Daily Diary", font=("arial", 30, 'bold'), bg="#d7dae2")
    diary_label.pack(pady=20)

    diary_text = Text(diary_window, font=("arial", 20), width=80, height=15)
    diary_text.pack(pady=20)

    def save_diary():
        diary_content = diary_text.get("1.0", END).strip()
        if diary_content:
            current_time = datetime.now().strftime("%d-%m-%Y %H:%M:%S")
            entry = f"Entry Date and Time: {current_time}\n\n{diary_content}\n\n{'-'*40}\n\n"
    
            # Encrypt the diary entry
            encrypted_entry = cipher_suite.encrypt(entry.encode())
    
            try:
                # Temporarily change file permissions to allow writing
                os.chmod("diary.txt", 0o666)  # Read and write permissions
                with open("diary.txt", "ab") as file:
                    file.write(encrypted_entry + b"\n")
                # Set file to read-only after writing
                os.chmod("diary.txt", 0o444)
                messagebox.showinfo("Saved", "Your diary entry has been saved and encrypted.")
            except PermissionError as e:
                messagebox.showerror("Permission Error", f"Error accessing file: {e}")
            except Exception as e:
                messagebox.showerror("Error", f"An unexpected error occurred: {e}")
            
            diary_text.delete("1.0", END)
        else:
            messagebox.showwarning("Empty", "Diary entry is empty.")

    Button(diary_window, text="Save Diary", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=save_diary).place(x=590, y=620)
def delete_diary_file():
    try:
        if os.path.exists("diary.txt"):
            os.remove("diary.txt")
            messagebox.showinfo("Deleted", "Diary file has been deleted.")
        else:
            messagebox.showwarning("Not Found", "Diary file does not exist.")
    except Exception as e:
        messagebox.showerror("Error", f"An error occurred while deleting the file: {e}")
def read_diary():
    if os.path.exists("diary.txt"):
        with open("diary.txt", "rb") as file:
            encrypted_entries = file.readlines()

        decrypted_content = ""
        for encrypted_entry in encrypted_entries:
            try:
                decrypted_content += cipher_suite.decrypt(encrypted_entry.strip()).decode() + "\n"
            except Exception as e:
                messagebox.showerror("Decryption Error", f"Error decrypting entry: {e}")
                continue

        # Display the decrypted content
        read_window = Toplevel(screen)
        read_window.title("View Diary")
        read_window.geometry("1280x720+150+70")
        read_window.configure(bg="#d7dae2")
        read_window.resizable(False, False)

        diary_label = Label(read_window, text="Your Encrypted Diary Entries", font=("arial", 30, 'bold'), bg="#d7dae2")
        diary_label.pack(pady=20)

        diary_text = Text(read_window, font=("arial", 20), width=80, height=20)
        diary_text.insert(END, decrypted_content)
        diary_text.pack(pady=20)

    else:
        messagebox.showwarning("No Entries", "No diary entries found.")

def login():
    u = un.get()
    c = pw.get()

    if u == "Parvat" and c == "1234":        
        open_diary()
    elif u == "" and c == "":
        messagebox.showerror("Invalid", "Please enter username and password")
    elif u == "":
        messagebox.showerror("Invalid", "Please enter username")
    elif c == "":
        messagebox.showerror("Invalid", "Please enter password")
    elif u != "Parvat" and c != "1234":
        messagebox.showerror("Invalid", "Invalid username and password")
    elif u != "Parvat":
        messagebox.showerror("Invalid", "Invalid username")
    elif c != "1234":
        messagebox.showerror("Invalid", "Invalid password")

def main_screen():
    global screen
    global un
    global pw

    screen = Tk()
    screen.geometry("1280x720+150+80")
    screen.configure(bg="#d7dae2")

    img = Image.open("p1.png")
    i_i = ImageTk.PhotoImage(img)
    screen.iconphoto(False, i_i)
    screen.title("Login System")

    lt = Label(text="Login System", font=("arial", 50, 'bold'), fg="black", bg="#d7dae2")
    lt.pack(pady=50)

    bc = Frame(screen, bg="black", width=800, height=400)
    bc.pack(pady=20)

    mf = Frame(bc, bg="#d7dae2", width=800, height=400)
    mf.pack(padx=20, pady=20)

    Label(mf, text="Username", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=50)
    Label(mf, text="Password", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=150)
    un = StringVar()
    pw = StringVar()

    eu = Entry(mf, textvariable=un, width=12, bd=2, font=("arial", 30))
    eu.place(x=400, y=50)
    ep = Entry(mf, textvariable=pw, width=12, bd=2, font=("arial", 30), show="*")
    ep.place(x=400, y=150)

    def reset():
        eu.delete(0, END)
        ep.delete(0, END)

    Button(mf, text="Login", height="2", width=23, bg="#ed3833", fg="white", bd=0, command=login).place(x=100, y=250)
    Button(mf, text="Reset", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=reset).place(x=300, y=250)
    Button(mf, text="Exit", height="2", width=23, bg="#00bd56", fg="white", bd=0, command=screen.destroy).place(x=500, y=250)
    Button(mf, text="Read Diary", height="2", width=23, bg="#ff8c00", fg="white", bd=0, command=read_diary).place(x=700, y=250)

    screen.mainloop()

main_screen()

# %%
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk
from datetime import datetime
import os
from cryptography.fernet import Fernet

# Generate a key for encryption
# Save the key securely for decryption later
key = Fernet.generate_key()
cipher_suite = Fernet(key)

def open_diary():
    # New window for writing daily diary
    diary_window = Toplevel(screen)
    diary_window.title("Daily Diary")
    diary_window.geometry("1280x720+150+70")
    diary_window.configure(bg="#d7dae2")
    diary_window.resizable(False, False)

    diary_label = Label(diary_window, text="Write Your Daily Diary", font=("arial", 30, 'bold'), bg="#d7dae2")
    diary_label.pack(pady=20)

    diary_text = Text(diary_window, font=("arial", 20), width=80, height=15)
    diary_text.pack(pady=20)

    def save_diary():
        diary_content = diary_text.get("1.0", END).strip()
        if diary_content:
            current_time = datetime.now().strftime("%d-%m-%Y %H:%M:%S")
            entry = f"Entry Date and Time: {current_time}\n\n{diary_content}\n\n{'-'*40}\n\n"
    
            # Encrypt the diary entry
            encrypted_entry = cipher_suite.encrypt(entry.encode())
    
            try:
                # Check file permissions and ensure it is writable
                if os.path.exists("diary1.txt"):
                    os.chmod("diary1.txt", 0o666)  # Make sure we have write permissions
                else:
                    # Create the file if it doesn't exist
                    open("diary1.txt", "wb").close()
                with open("diary1.txt", "ab") as file:
                    file.write(encrypted_entry + b"\n")
                os.chmod("diary1.txt", 0o444)  # Set file to read-only after writing
                messagebox.showinfo("Saved", "Your diary entry has been saved and encrypted.")
            except PermissionError as e:
                messagebox.showerror("Permission Error", f"Permission error: {e}")
            except Exception as e:
                messagebox.showerror("Error", f"An unexpected error occurred: {e}")
            
            diary_text.delete("1.0", END)
        else:
            messagebox.showwarning("Empty", "Diary entry is empty.")

    Button(diary_window, text="Save Diary", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=save_diary).place(x=550, y=620)
    Button(diary_window, text="Delete Diary File", height="2", width=23, bg="#ff0000", fg="white", bd=0, command=delete_diary_file).place(x=700, y=620)
    Button(diary_window, text="Read Diary", height="2", width=23, bg="#ff8c00", fg="white", bd=0, command=read_diary).place(x=760, y=620)

def delete_diary_file():
    try:
        # Check if the file exists before attempting to delete
        if os.path.exists("diary1.txt"):
            os.chmod("diary1.txt", 0o666)  # Ensure permissions are set
            os.remove("diary1.txt")
            messagebox.showinfo("Deleted", "Diary file has been deleted.")
        else:
            messagebox.showwarning("Not Found", "Diary file does not exist.")
    except FileNotFoundError:
        messagebox.showwarning("Not Found", "Diary file does not exist.")
    except PermissionError:
        messagebox.showerror("Permission Error", "Permission denied while trying to delete the file.")
    except Exception as e:
        messagebox.showerror("Error", f"An error occurred while deleting the file: {e}")

def read_diary():
    if os.path.exists("diary1.txt"):
        try:
            with open("diary1.txt", "rb") as file:
                encrypted_entries = file.readlines()

            decrypted_content = ""
            for encrypted_entry in encrypted_entries:
                try:
                    decrypted_content += cipher_suite.decrypt(encrypted_entry.strip()).decode() + "\n"
                except Exception as e:
                    messagebox.showerror("Decryption Error", f"Error decrypting entry: {e}")
                    continue

            # Display the decrypted content
            read_window = Toplevel(screen)
            read_window.title("View Diary")
            read_window.geometry("1280x720+150+70")
            read_window.configure(bg="#d7dae2")
            read_window.resizable(False, False)

            diary_label = Label(read_window, text="Your Encrypted Diary Entries", font=("arial", 30, 'bold'), bg="#d7dae2")
            diary_label.pack(pady=20)

            diary_text = Text(read_window, font=("arial", 20), width=80, height=20)
            diary_text.insert(END, decrypted_content)
            diary_text.pack(pady=20)

        except Exception as e:
            messagebox.showerror("Error", f"An unexpected error occurred: {e}")
    else:
        messagebox.showwarning("No Entries", "No diary entries found.")

def login():
    u = un.get()
    c = pw.get()

    if u == "Parvat" and c == "1234":        
        open_diary()
    elif u == "" and c == "":
        messagebox.showerror("Invalid", "Please enter username and password")
    elif u == "":
        messagebox.showerror("Invalid", "Please enter username")
    elif c == "":
        messagebox.showerror("Invalid", "Please enter password")
    elif u != "Parvat" and c != "1234":
        messagebox.showerror("Invalid", "Invalid username and password")
    elif u != "Parvat":
        messagebox.showerror("Invalid", "Invalid username")
    elif c != "1234":
        messagebox.showerror("Invalid", "Invalid password")

def main_screen():
    global screen
    global un
    global pw

    screen = Tk()
    screen.geometry("1280x720+150+80")
    screen.configure(bg="#d7dae2")

    img = Image.open("p1.png")
    i_i = ImageTk.PhotoImage(img)
    screen.iconphoto(False, i_i)
    screen.title("Login System")

    lt = Label(text="Login System", font=("arial", 50, 'bold'), fg="black", bg="#d7dae2")
    lt.pack(pady=50)

    bc = Frame(screen, bg="black", width=800, height=400)
    bc.pack(pady=20)

    mf = Frame(bc, bg="#d7dae2", width=800, height=400)
    mf.pack(padx=20, pady=20)

    Label(mf, text="Username", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=50)
    Label(mf, text="Password", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=150)
    un = StringVar()
    pw = StringVar()

    eu = Entry(mf, textvariable=un, width=12, bd=2, font=("arial", 30))
    eu.place(x=400, y=50)
    ep = Entry(mf, textvariable=pw, width=12, bd=2, font=("arial", 30), show="*")
    ep.place(x=400, y=150)

    def reset():
        eu.delete(0, END)
        ep.delete(0, END)

    Button(mf, text="Login", height="2", width=23, bg="#ed3833", fg="white", bd=0, command=login).place(x=100, y=250)
    Button(mf, text="Reset", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=reset).place(x=300, y=250)
    Button(mf, text="Exit", height="2", width=23, bg="#00bd56", fg="white", bd=0, command=screen.destroy).place(x=500, y=250)
   
    

    screen.mainloop()

main_screen()

# %%
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk
from datetime import datetime
import os
from cryptography.fernet import Fernet

# Generate a key for encryption
# Save the key securely for decryption later
key = Fernet.generate_key()
cipher_suite = Fernet(key)

def open_diary():
    # New window for writing daily diary
    diary_window = Toplevel(screen)
    diary_window.title("Daily Diary")
    diary_window.geometry("1280x720+150+70")
    diary_window.configure(bg="#d7dae2")
    diary_window.resizable(False, False)

    diary_label = Label(diary_window, text="Write Your Daily Diary", font=("arial", 30, 'bold'), bg="#d7dae2")
    diary_label.pack(pady=20)

    diary_text = Text(diary_window, font=("arial", 20), width=80, height=15)
    diary_text.pack(pady=20)

    def save_diary():
        diary_content = diary_text.get("1.0", END).strip()
        if diary_content:
            current_time = datetime.now().strftime("%d-%m-%Y %H:%M:%S")
            entry = f"Entry Date and Time: {current_time}\n\n{diary_content}\n\n{'-'*40}\n\n"
    
            # Encrypt the diary entry
            encrypted_entry = cipher_suite.encrypt(entry.encode())
    
            try:
                # Check file permissions and ensure it is writable
                if os.path.exists("diary1.txt"):
                    os.chmod("diary1.txt", 0o666)  # Make sure we have write permissions
                else:
                    # Create the file if it doesn't exist
                    open("diary1.txt", "wb").close()
                with open("diary1.txt", "ab") as file:
                    file.write(encrypted_entry + b"\n")
                os.chmod("diary1.txt", 0o444)  # Set file to read-only after writing
                messagebox.showinfo("Saved", "Your diary entry has been saved and encrypted.")
            except PermissionError as e:
                messagebox.showerror("Permission Error", f"Permission error: {e}")
            except Exception as e:
                messagebox.showerror("Error", f"An unexpected error occurred: {e}")
            
            diary_text.delete("1.0", END)
        else:
            messagebox.showwarning("Empty", "Diary entry is empty.")

    Button(diary_window, text="Save Diary", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=save_diary).place(x=550, y=620)
    Button(diary_window, text="Delete Diary File", height="2", width=23, bg="#ff0000", fg="white", bd=0, command=delete_diary_file).place(x=700, y=620)
    Button(diary_window, text="Read Diary", height="2", width=23, bg="#ff8c00", fg="white", bd=0, command=read_diary).place(x=760, y=620)

def delete_diary_file():
    try:
        # Check if the file exists before attempting to delete
        if os.path.exists("diary1.txt"):
            os.chmod("diary1.txt", 0o666)  # Ensure permissions are set
            os.remove("diary1.txt")
            messagebox.showinfo("Deleted", "Diary file has been deleted.")
        else:
            messagebox.showwarning("Not Found", "Diary file does not exist.")
    except FileNotFoundError:
        messagebox.showwarning("Not Found", "Diary file does not exist.")
    except PermissionError:
        messagebox.showerror("Permission Error", "Permission denied while trying to delete the file.")
    except Exception as e:
        messagebox.showerror("Error", f"An error occurred while deleting the file: {e}")

def read_diary():
    if os.path.exists("diary1.txt"):
        try:
            with open("diary1.txt", "rb") as file:
                encrypted_entries = file.readlines()

            decrypted_content = ""
            for encrypted_entry in encrypted_entries:
                try:
                    decrypted_content += cipher_suite.decrypt(encrypted_entry.strip()).decode() + "\n"
                except Exception as e:
                    messagebox.showerror("Decryption Error", f"Error decrypting entry: {e}")
                    continue

            # Display the decrypted content
            read_window = Toplevel(screen)
            read_window.title("View Diary")
            read_window.geometry("1280x720+150+70")
            read_window.configure(bg="#d7dae2")
            read_window.resizable(False, False)

            diary_label = Label(read_window, text="Your Encrypted Diary Entries", font=("arial", 30, 'bold'), bg="#d7dae2")
            diary_label.pack(pady=20)

            diary_text = Text(read_window, font=("arial", 20), width=80, height=20)
            diary_text.insert(END, decrypted_content)
            diary_text.pack(pady=20)

        except Exception as e:
            messagebox.showerror("Error", f"An unexpected error occurred: {e}")
    else:
        messagebox.showwarning("No Entries", "No diary entries found.")

def login():
    u = un.get()
    c = pw.get()

    if u == "Parvat" and c == "1234":        
        open_diary()
    elif u == "" and c == "":
        messagebox.showerror("Invalid", "Please enter username and password")
    elif u == "":
        messagebox.showerror("Invalid", "Please enter username")
    elif c == "":
        messagebox.showerror("Invalid", "Please enter password")
    elif u != "Parvat" and c != "1234":
        messagebox.showerror("Invalid", "Invalid username and password")
    elif u != "Parvat":
        messagebox.showerror("Invalid", "Invalid username")
    elif c != "1234":
        messagebox.showerror("Invalid", "Invalid password")

def main_screen():
    global screen
    global un
    global pw

    screen = Tk()
    screen.geometry("1280x720+150+80")
    screen.configure(bg="#d7dae2")

    img = Image.open("p1.png")
    i_i = ImageTk.PhotoImage(img)
    screen.iconphoto(False, i_i)
    screen.title("Login System")

    lt = Label(text="Login System", font=("arial", 50, 'bold'), fg="black", bg="#d7dae2")
    lt.pack(pady=50)

    bc = Frame(screen, bg="black", width=800, height=400)
    bc.pack(pady=20)

    mf = Frame(bc, bg="#d7dae2", width=800, height=400)
    mf.pack(padx=20, pady=20)

    Label(mf, text="Username", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=50)
    Label(mf, text="Password", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=150)
    un = StringVar()
    pw = StringVar()

    eu = Entry(mf, textvariable=un, width=12, bd=2, font=("arial", 30))
    eu.place(x=400, y=50)
    ep = Entry(mf, textvariable=pw, width=12, bd=2, font=("arial", 30), show="*")
    ep.place(x=400, y=150)

    def reset():
        eu.delete(0, END)
        ep.delete(0, END)

    Button(mf, text="Login", height="2", width=23, bg="#ed3833", fg="white", bd=0, command=login).place(x=100, y=250)
    Button(mf, text="Reset", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=reset).place(x=300, y=250)
    Button(mf, text="Exit", height="2", width=23, bg="#00bd56", fg="white", bd=0, command=screen.destroy).place(x=500, y=250)
   
    

    screen.mainloop()

main_screen()

# %%
from cryptography.fernet import Fernet

# Generate and print the key
key = Fernet.generate_key()
print(key.decode())  # Print the key as a string to copy
# Out:
# yGsf2pqXSzNtnbxZEqR1WvM_FI4maUo0cXVk3G7MiJg=

# %%
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk
from datetime import datetime
import os
from cryptography.fernet import Fernet

# Use your static key here
STATIC_KEY = b'yGsf2pqXSzNtnbxZEqR1WvM_FI4maUo0cXVk3G7MiJg='  
cipher_suite = Fernet(STATIC_KEY)

def open_diary():
    diary_window = Toplevel(screen)
    diary_window.title("Daily Diary")
    diary_window.geometry("1280x720+150+70")
    diary_window.configure(bg="#d7dae2")
    diary_window.resizable(False, False)

    diary_label = Label(diary_window, text="Write Your Daily Diary", font=("arial", 30, 'bold'), bg="#d7dae2")
    diary_label.pack(pady=20)

    diary_text = Text(diary_window, font=("arial", 20), width=80, height=15)
    diary_text.pack(pady=20)

    def save_diary():
        diary_content = diary_text.get("1.0", END).strip()
        if diary_content:
            current_time = datetime.now().strftime("%d-%m-%Y %H:%M:%S")
            entry = f"Entry Date and Time: {current_time}\n\n{diary_content}\n\n{'-'*40}\n\n"

            encrypted_entry = cipher_suite.encrypt(entry.encode())

            try:
                if os.path.exists("diary1.txt"):
                    os.chmod("diary1.txt", 0o666)
                else:
                    open("diary1.txt", "wb").close()
                with open("diary1.txt", "ab") as file:
                    file.write(encrypted_entry + b"\n")
                os.chmod("diary1.txt", 0o444)
                messagebox.showinfo("Saved", "Your diary entry has been saved and encrypted.")
            except PermissionError as e:
                messagebox.showerror("Permission Error", f"Permission error: {e}")
            except Exception as e:
                messagebox.showerror("Error", f"An unexpected error occurred: {e}")

            diary_text.delete("1.0", END)
        else:
            messagebox.showwarning("Empty", "Diary entry is empty.")

    Button(diary_window, text="Save Diary", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=save_diary).place(x=550, y=620)
    Button(diary_window, text="Delete Diary File", height="2", width=23, bg="#ff0000", fg="white", bd=0, command=delete_diary_file).place(x=700, y=620)
    Button(diary_window, text="Read Diary", height="2", width=23, bg="#ff8c00", fg="white", bd=0, command=read_diary).place(x=760, y=620)

def delete_diary_file():
    try:
        if os.path.exists("diary1.txt"):
            os.chmod("diary1.txt", 0o666)
            os.remove("diary1.txt")
            messagebox.showinfo("Deleted", "Diary file has been deleted.")
        else:
            messagebox.showwarning("Not Found", "Diary file does not exist.")
    except FileNotFoundError:
        messagebox.showwarning("Not Found", "Diary file does not exist.")
    except PermissionError:
        messagebox.showerror("Permission Error", "Permission denied while trying to delete the file.")
    except Exception as e:
        messagebox.showerror("Error", f"An error occurred while deleting the file: {e}")

def read_diary():
    if os.path.exists("diary1.txt"):
        try:
            with open("diary1.txt", "rb") as file:
                encrypted_entries = file.readlines()

            decrypted_content = ""
            for encrypted_entry in encrypted_entries:
                try:
                    decrypted_content += cipher_suite.decrypt(encrypted_entry.strip()).decode() + "\n"
                except Exception as e:
                    messagebox.showerror("Decryption Error", f"Error decrypting entry: {e}")
                    continue

            read_window = Toplevel(screen)
            read_window.title("View Diary")
            read_window.geometry("1280x720+150+70")
            read_window.configure(bg="#d7dae2")
            read_window.resizable(False, False)

            diary_label = Label(read_window, text="Your Encrypted Diary Entries", font=("arial", 30, 'bold'), bg="#d7dae2")
            diary_label.pack(pady=20)

            diary_text = Text(read_window, font=("arial", 20), width=80, height=20)
            diary_text.insert(END, decrypted_content)
            diary_text.pack(pady=20)

        except Exception as e:
            messagebox.showerror("Error", f"An unexpected error occurred: {e}")
    else:
        messagebox.showwarning("No Entries", "No diary entries found.")

def login():
    u = un.get()
    c = pw.get()

    if u == "Parvat" and c == "1234":
        open_diary()
    elif u == "" and c == "":
        messagebox.showerror("Invalid", "Please enter username and password")
    elif u == "":
        messagebox.showerror("Invalid", "Please enter username")
    elif c == "":
        messagebox.showerror("Invalid", "Please enter password")
    elif u != "Parvat" and c != "1234":
        messagebox.showerror("Invalid", "Invalid username and password")
    elif u != "Parvat":
        messagebox.showerror("Invalid", "Invalid username")
    elif c != "1234":
        messagebox.showerror("Invalid", "Invalid password")

def main_screen():
    global screen
    global un
    global pw

    screen = Tk()
    screen.geometry("1280x720+150+80")
    screen.configure(bg="#d7dae2")

    img = Image.open("p1.png")
    i_i = ImageTk.PhotoImage(img)
    screen.iconphoto(False, i_i)
    screen.title("Login System")

    lt = Label(text="Login System", font=("arial", 50, 'bold'), fg="black", bg="#d7dae2")
    lt.pack(pady=50)

    bc = Frame(screen, bg="black", width=800, height=400)
    bc.pack(pady=20)

    mf = Frame(bc, bg="#d7dae2", width=800, height=400)
    mf.pack(padx=20, pady=20)

    Label(mf, text="Username", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=50)
    Label(mf, text="Password", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=150)
    un = StringVar()
    pw = StringVar()

    eu = Entry(mf, textvariable=un, width=12, bd=2, font=("arial", 30))
    eu.place(x=400, y=50)
    ep = Entry(mf, textvariable=pw, width=12, bd=2, font=("arial", 30), show="*")
    ep.place(x=400, y=150)

    def reset():
        eu.delete(0, END)
        ep.delete(0, END)

    Button(mf, text="Login", height="2", width=23, bg="#ed3833", fg="white", bd=0, command=login).place(x=100, y=250)
    Button(mf, text="Reset", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=reset).place(x=300, y=250)
    Button(mf, text="Exit", height="2", width=23, bg="#00bd56", fg="white", bd=0, command=screen.destroy).place(x=500, y=250)

    screen.mainloop()

main_screen()

# %%
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk
from datetime import datetime
import os
from cryptography.fernet import Fernet

# Use your static key here
STATIC_KEY = b'yGsf2pqXSzNtnbxZEqR1WvM_FI4maUo0cXVk3G7MiJg='  
cipher_suite = Fernet(STATIC_KEY)



def delete_diary_file():
    try:
        if os.path.exists("diary1.txt"):
            os.chmod("diary1.txt", 0o666)
            os.remove("diary1.txt")
            messagebox.showinfo("Deleted", "Diary file has been deleted.")
        else:
            messagebox.showwarning("Not Found", "Diary file does not exist.")
    except FileNotFoundError:
        messagebox.showwarning("Not Found", "Diary file does not exist.")
    except PermissionError:
        messagebox.showerror("Permission Error", "Permission denied while trying to delete the file.")
    except Exception as e:
        messagebox.showerror("Error", f"An error occurred while deleting the file: {e}")

def read_diary():
    if os.path.exists("diary1.txt"):
        try:
            with open("diary1.txt", "rb") as file:
                encrypted_entries = file.readlines()

            decrypted_content = ""
            for encrypted_entry in encrypted_entries:
                try:
                    decrypted_content += cipher_suite.decrypt(encrypted_entry.strip()).decode() + "\n"
                except Exception as e:
                    messagebox.showerror("Decryption Error", f"Error decrypting entry: {e}")
                    continue

            read_window = Toplevel(screen)
            read_window.title("View Diary")
            read_window.geometry("1280x720+150+70")
            read_window.configure(bg="#d7dae2")
            read_window.resizable(False, False)

            diary_label = Label(read_window, text="Your Encrypted Diary Entries", font=("arial", 30, 'bold'), bg="#d7dae2")
            diary_label.pack(pady=20)

            diary_text = Text(read_window, font=("arial", 20), width=80, height=20)
            diary_text.insert(END, decrypted_content)
            diary_text.pack(pady=20)

        except Exception as e:
            messagebox.showerror("Error", f"An unexpected error occurred: {e}")
    else:
        messagebox.showwarning("No Entries", "No diary entries found.")

def open_diary():
    diary_window = Toplevel(screen)
    diary_window.title("Daily Diary")
    diary_window.geometry("1280x720+150+70")
    diary_window.configure(bg="#d7dae2")
    diary_window.resizable(False, False)

    diary_label = Label(diary_window, text="Write Your Daily Diary", font=("arial", 30, 'bold'), bg="#d7dae2")
    diary_label.pack(pady=20)

    diary_text = Text(diary_window, font=("arial", 20), width=80, height=15)
    diary_text.pack(pady=20)

    def save_diary():
        diary_content = diary_text.get("1.0", END).strip()
        if diary_content:
            current_time = datetime.now().strftime("%d-%m-%Y %H:%M:%S")
            entry = f"Entry Date and Time: {current_time}\n\n{diary_content}\n\n{'-'*40}\n\n"

            encrypted_entry = cipher_suite.encrypt(entry.encode())

            try:
                if os.path.exists("diary1.txt"):
                    os.chmod("diary1.txt", 0o666)
                else:
                    open("diary1.txt", "wb").close()
                with open("diary1.txt", "ab") as file:
                    file.write(encrypted_entry + b"\n")
                os.chmod("diary1.txt", 0o444)
                messagebox.showinfo("Saved", "Your diary entry has been saved and encrypted.")
            except PermissionError as e:
                messagebox.showerror("Permission Error", f"Permission error: {e}")
            except Exception as e:
                messagebox.showerror("Error", f"An unexpected error occurred: {e}")

            diary_text.delete("1.0", END)
        else:
            messagebox.showwarning("Empty", "Diary entry is empty.")

    Button(diary_window, text="Save Diary", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=save_diary).place(x=550, y=620)
    Button(diary_window, text="Delete Diary File", height="2", width=23, bg="#ff0000", fg="white", bd=0, command=delete_diary_file).place(x=700, y=620)
    Button(diary_window, text="Read Diary", height="2", width=23, bg="#ff8c00", fg="white", bd=0, command=read_diary).place(x=760, y=620)

def login():
    u = un.get()
    c = pw.get()

    if u == "Parvat" and c == "1234":
        open_diary()
    elif u == "" and c == "":
        messagebox.showerror("Invalid", "Please enter username and password")
    elif u == "":
        messagebox.showerror("Invalid", "Please enter username")
    elif c == "":
        messagebox.showerror("Invalid", "Please enter password")
    elif u != "Parvat" and c != "1234":
        messagebox.showerror("Invalid", "Invalid username and password")
    elif u != "Parvat":
        messagebox.showerror("Invalid", "Invalid username")
    elif c != "1234":
        messagebox.showerror("Invalid", "Invalid password")

def main_screen():
    global screen
    global un
    global pw

    screen = Tk()
    screen.geometry("1280x720+150+80")
    screen.configure(bg="#d7dae2")

    img = Image.open("p1.png")
    i_i = ImageTk.PhotoImage(img)
    screen.iconphoto(False, i_i)
    screen.title("Login System")

    lt = Label(text="Login System", font=("arial", 50, 'bold'), fg="black", bg="#d7dae2")
    lt.pack(pady=50)

    bc = Frame(screen, bg="black", width=800, height=400)
    bc.pack(pady=20)

    mf = Frame(bc, bg="#d7dae2", width=800, height=400)
    mf.pack(padx=20, pady=20)

    Label(mf, text="Username", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=50)
    Label(mf, text="Password", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=150)
    un = StringVar()
    pw = StringVar()

    eu = Entry(mf, textvariable=un, width=12, bd=2, font=("arial", 30))
    eu.place(x=400, y=50)
    ep = Entry(mf, textvariable=pw, width=12, bd=2, font=("arial", 30), show="*")
    ep.place(x=400, y=150)

    def reset():
        eu.delete(0, END)
        ep.delete(0, END)

    Button(mf, text="Login", height="2", width=23, bg="#ed3833", fg="white", bd=0, command=login).place(x=100, y=250)
    Button(mf, text="Reset", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=reset).place(x=300, y=250)
    Button(mf, text="Exit", height="2", width=23, bg="#00bd56", fg="white", bd=0, command=screen.destroy).place(x=500, y=250)

    screen.mainloop()

main_screen()

# %%
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk
import mysql.connector
from mysql.connector import Error
from datetime import datetime
import os
from cryptography.fernet import Fernet




db_config = {
    'user': 'root',
    'password': '11223344minmin',
    'host': 'localhost',
    'database': 'diary'
}

def get_user(username):
    conn = mysql.connector.connect(**db_config)
    cursor = conn.cursor(dictionary=True)
    cursor.execute("SELECT username, password,keyvalue FROM users WHERE username = %s", (username,))
    user = cursor.fetchone()
    cursor.close()
    conn.close()
    return user

def delete_diary_file():
    try:
        if os.path.exists("diary1.txt"):
            os.chmod("diary1.txt", 0o666)
            os.remove("diary1.txt")
            messagebox.showinfo("Deleted", "Diary file has been deleted.")
        else:
            messagebox.showwarning("Not Found", "Diary file does not exist.")
    except FileNotFoundError:
        messagebox.showwarning("Not Found", "Diary file does not exist.")
    except PermissionError:
        messagebox.showerror("Permission Error", "Permission denied while trying to delete the file.")
    except Exception as e:
        messagebox.showerror("Error", f"An error occurred while deleting the file: {e}")

def read_diary():
    if os.path.exists("diary1.txt"):
        try:
            with open("diary1.txt", "rb") as file:
                encrypted_entries = file.readlines()

            decrypted_content = ""
            for encrypted_entry in encrypted_entries:
                try:
                    decrypted_content += cipher_suite.decrypt(encrypted_entry.strip()).decode() + "\n"
                except Exception as e:
                    messagebox.showerror("Decryption Error", f"Error decrypting entry: {e}")
                    continue

            read_window = Toplevel(screen)
            read_window.title("View Diary")
            read_window.geometry("1280x720+150+70")
            read_window.configure(bg="#d7dae2")
            read_window.resizable(False, False)

            diary_label = Label(read_window, text="Your Encrypted Diary Entries", font=("arial", 30, 'bold'), bg="#d7dae2")
            diary_label.pack(pady=20)

            diary_text = Text(read_window, font=("arial", 20), width=80, height=20)
            diary_text.insert(END, decrypted_content)
            diary_text.pack(pady=20)

        except Exception as e:
            messagebox.showerror("Error", f"An unexpected error occurred: {e}")
    else:
        messagebox.showwarning("No Entries", "No diary entries found.")

def open_diary():
    diary_window = Toplevel(screen)
    diary_window.title("Daily Diary")
    diary_window.geometry("1280x720+150+70")
    diary_window.configure(bg="#d7dae2")
    diary_window.resizable(False, False)

    diary_label = Label(diary_window, text="Write Your Daily Diary", font=("arial", 30, 'bold'), bg="#d7dae2")
    diary_label.pack(pady=20)

    diary_text = Text(diary_window, font=("arial", 20), width=80, height=15)
    diary_text.pack(pady=20)

    def save_diary():
        diary_content = diary_text.get("1.0", END).strip()
        if diary_content:
            current_time = datetime.now().strftime("%d-%m-%Y %H:%M:%S")
            entry = f"Entry Date and Time: {current_time}\n\n{diary_content}\n\n{'-'*40}\n\n"

            encrypted_entry = cipher_suite.encrypt(entry.encode())

            try:
                if os.path.exists("diary1.txt"):
                    os.chmod("diary1.txt", 0o666)
                else:
                    open("diary1.txt", "wb").close()
                with open("diary1.txt", "ab") as file:
                    file.write(encrypted_entry + b"\n")
                os.chmod("diary1.txt", 0o444)
                messagebox.showinfo("Saved", "Your diary entry has been saved and encrypted.")
            except PermissionError as e:
                messagebox.showerror("Permission Error", f"Permission error: {e}")
            except Exception as e:
                messagebox.showerror("Error", f"An unexpected error occurred: {e}")

            diary_text.delete("1.0", END)
        else:
            messagebox.showwarning("Empty", "Diary entry is empty.")

    Button(diary_window, text="Save Diary", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=save_diary).place(x=550, y=620)
    Button(diary_window, text="Delete Diary File", height="2", width=23, bg="#ff0000", fg="white", bd=0, command=delete_diary_file).place(x=700, y=620)
    Button(diary_window, text="Read Diary", height="2", width=23, bg="#ff8c00", fg="white", bd=0, command=read_diary).place(x=760, y=620)

def login():
    global STATIC_KEY, cipher_suite
    username = un.get()
    password = pw.get()

    user = get_user(username)

    if user:
        if user['password'] == password:
            STATIC_KEY = user['keyvalue'].encode() 
            cipher_suite = Fernet(STATIC_KEY)
            open_diary()
        else:
            messagebox.showerror("Invalid", "Invalid password")
    else:
        messagebox.showerror("Invalid", "Invalid username")

def main_screen():
    global screen
    global un
    global pw

    screen = Tk()
    screen.geometry("1280x720+150+80")
    screen.configure(bg="#d7dae2")

    img = Image.open("p1.png")
    i_i = ImageTk.PhotoImage(img)
    screen.iconphoto(False, i_i)
    screen.title("Login System")

    lt = Label(text="Login System", font=("arial", 50, 'bold'), fg="black", bg="#d7dae2")
    lt.pack(pady=50)

    bc = Frame(screen, bg="black", width=800, height=400)
    bc.pack(pady=20)

    mf = Frame(bc, bg="#d7dae2", width=800, height=400)
    mf.pack(padx=20, pady=20)

    Label(mf, text="Username", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=50)
    Label(mf, text="Password", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=150)
    un = StringVar()
    pw = StringVar()

    eu = Entry(mf, textvariable=un, width=12, bd=2, font=("arial", 30))
    eu.place(x=400, y=50)
    ep = Entry(mf, textvariable=pw, width=12, bd=2, font=("arial", 30), show="*")
    ep.place(x=400, y=150)

    def reset():
        eu.delete(0, END)
        ep.delete(0, END)

    Button(mf, text="Login", height="2", width=23, bg="#ed3833", fg="white", bd=0, command=login).place(x=100, y=250)
    Button(mf, text="Reset", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=reset).place(x=300, y=250)
    Button(mf, text="Exit", height="2", width=23, bg="#00bd56", fg="white", bd=0, command=screen.destroy).place(x=500, y=250)

    screen.mainloop()

main_screen()
#from cryptography.fernet import Fernet

# Generate and print the key
#key = Fernet.generate_key()
#print(key.decode())  # Print the key as a string to copy

# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB 163.8 kB/s eta 0:01:28
#    ---------------------------------------- 0.0/14.3 MB 163.4 kB/s eta 0:01:28
#    ---------------------------------------- 0.1/14.3 MB 231.0 kB/s eta 0:01:02
#    ---------------------------------------- 0.1/14.3 MB 344.8 kB/s eta 0:00:42
#    ---------------------------------------- 0.2/14.3 MB 455.1 kB/s eta 0:00:32
#     --------------------------------------- 0.2/14.3 MB 553.5 kB/s eta 0:00:26
#     --------------------------------------- 0.4/14.3 MB 766.9 kB/s eta 0:00:19
# ...

# %%
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk
import mysql.connector
from mysql.connector import Error
from datetime import datetime
import os
from cryptography.fernet import Fernet




db_config = {
    'user': 'root',
    'password': '11223344minmin',
    'host': 'localhost',
    'database': 'diary'
}

def get_user(username):
    conn = mysql.connector.connect(**db_config)
    cursor = conn.cursor(dictionary=True)
    cursor.execute("SELECT username, password,keyvalue FROM users WHERE username = %s", (username,))
    user = cursor.fetchone()
    cursor.close()
    conn.close()
    return user

def delete_diary_file():
    try:
        if os.path.exists("diary1.txt"):
            os.chmod("diary1.txt", 0o666)
            os.remove("diary1.txt")
            messagebox.showinfo("Deleted", "Diary file has been deleted.")
        else:
            messagebox.showwarning("Not Found", "Diary file does not exist.")
    except FileNotFoundError:
        messagebox.showwarning("Not Found", "Diary file does not exist.")
    except PermissionError:
        messagebox.showerror("Permission Error", "Permission denied while trying to delete the file.")
    except Exception as e:
        messagebox.showerror("Error", f"An error occurred while deleting the file: {e}")

def read_diary():
    if os.path.exists("diary1.txt"):
        try:
            with open("diary1.txt", "rb") as file:
                encrypted_entries = file.readlines()

            decrypted_content = ""
            for encrypted_entry in encrypted_entries:
                try:
                    decrypted_content += cipher_suite.decrypt(encrypted_entry.strip()).decode() + "\n"
                except Exception as e:
                    messagebox.showerror("Decryption Error", f"Error decrypting entry: {e}")
                    continue

            read_window = Toplevel(screen)
            read_window.title("View Diary")
            read_window.geometry("1280x720+150+70")
            read_window.configure(bg="#d7dae2")
            read_window.resizable(False, False)

            diary_label = Label(read_window, text="Your Encrypted Diary Entries", font=("arial", 30, 'bold'), bg="#d7dae2")
            diary_label.pack(pady=20)

            diary_text = Text(read_window, font=("arial", 20), width=80, height=20)
            diary_text.insert(END, decrypted_content)
            diary_text.pack(pady=20)

        except Exception as e:
            messagebox.showerror("Error", f"An unexpected error occurred: {e}")
    else:
        messagebox.showwarning("No Entries", "No diary entries found.")

def open_diary():
    diary_window = Toplevel(screen)
    diary_window.title("Daily Diary")
    diary_window.geometry("1280x720+150+70")
    diary_window.configure(bg="#d7dae2")
    diary_window.resizable(False, False)

    diary_label = Label(diary_window, text="Write Your Daily Diary", font=("arial", 30, 'bold'), bg="#d7dae2")
    diary_label.pack(pady=20)

    diary_text = Text(diary_window, font=("arial", 20), width=80, height=15)
    diary_text.pack(pady=20)

    def save_diary():
        diary_content = diary_text.get("1.0", END).strip()
        if diary_content:
            current_time = datetime.now().strftime("%d-%m-%Y %H:%M:%S")
            entry = f"Entry Date and Time: {current_time}\n\n{diary_content}\n\n{'-'*40}\n\n"

            encrypted_entry = cipher_suite.encrypt(entry.encode())

            try:
                if os.path.exists("diary1.txt"):
                    os.chmod("diary1.txt", 0o666)
                else:
                    open("diary1.txt", "wb").close()
                with open("diary1.txt", "ab") as file:
                    file.write(encrypted_entry + b"\n")
                os.chmod("diary1.txt", 0o444)
                messagebox.showinfo("Saved", "Your diary entry has been saved and encrypted.")
            except PermissionError as e:
                messagebox.showerror("Permission Error", f"Permission error: {e}")
            except Exception as e:
                messagebox.showerror("Error", f"An unexpected error occurred: {e}")

            diary_text.delete("1.0", END)
        else:
            messagebox.showwarning("Empty", "Diary entry is empty.")

    Button(diary_window, text="Save Diary", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=save_diary).place(x=550, y=620)
    Button(diary_window, text="Delete Diary File", height="2", width=23, bg="#ff0000", fg="white", bd=0, command=delete_diary_file).place(x=700, y=620)
    Button(diary_window, text="Read Diary", height="2", width=23, bg="#ff8c00", fg="white", bd=0, command=read_diary).place(x=760, y=620)

def login():
    global STATIC_KEY, cipher_suite
    username = un.get()
    password = pw.get()

    user = get_user(username)

    if user:
        if user['password'] == password:
            STATIC_KEY = user['keyvalue'].encode() 
            cipher_suite = Fernet(STATIC_KEY)
            open_diary()
        else:
            messagebox.showerror("Invalid", "Invalid password")
    else:
        messagebox.showerror("Invalid", "Invalid username")

def main_screen():
    global screen
    global un
    global pw

    screen = Tk()
    screen.geometry("1280x720+150+80")
    screen.configure(bg="#d7dae2")

    img = Image.open("p1.png")
    i_i = ImageTk.PhotoImage(img)
    screen.iconphoto(False, i_i)
    screen.title("Login System")

    lt = Label(text="Login System", font=("arial", 50, 'bold'), fg="black", bg="#d7dae2")
    lt.pack(pady=50)

    bc = Frame(screen, bg="black", width=800, height=400)
    bc.pack(pady=20)

    mf = Frame(bc, bg="#d7dae2", width=800, height=400)
    mf.pack(padx=20, pady=20)

    Label(mf, text="Username", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=50)
    Label(mf, text="Password", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=150)
    un = StringVar()
    pw = StringVar()

    eu = Entry(mf, textvariable=un, width=12, bd=2, font=("arial", 30))
    eu.place(x=400, y=50)
    ep = Entry(mf, textvariable=pw, width=12, bd=2, font=("arial", 30), show="*")
    ep.place(x=400, y=150)

    def reset():
        eu.delete(0, END)
        ep.delete(0, END)

    Button(mf, text="Login", height="2", width=23, bg="#ed3833", fg="white", bd=0, command=login).place(x=100, y=250)
    Button(mf, text="Reset", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=reset).place(x=300, y=250)
    Button(mf, text="Exit", height="2", width=23, bg="#00bd56", fg="white", bd=0, command=screen.destroy).place(x=500, y=250)

    screen.mainloop()

main_screen()
#from cryptography.fernet import Fernet

# Generate and print the key
#key = Fernet.generate_key()
#print(key.decode())  # Print the key as a string to copy

# %%
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk
import mysql.connector
from mysql.connector import Error
from datetime import datetime
import os
from cryptography.fernet import Fernet




db_config = {
    'user': 'root',
    'password': '11223344minmin',
    'host': 'localhost',
    'database': 'diary'
}

def get_user(username):
    conn = mysql.connector.connect(**db_config)
    cursor = conn.cursor(dictionary=True)
    cursor.execute("SELECT username, password,keyvalue FROM users WHERE username = %s", (username,))
    user = cursor.fetchone()
    cursor.close()
    conn.close()
    return user

def delete_diary_file():
    try:
        if os.path.exists("diary1.txt"):
            os.chmod("diary1.txt", 0o666)
            os.remove("diary1.txt")
            messagebox.showinfo("Deleted", "Diary file has been deleted.")
        else:
            messagebox.showwarning("Not Found", "Diary file does not exist.")
    except FileNotFoundError:
        messagebox.showwarning("Not Found", "Diary file does not exist.")
    except PermissionError:
        messagebox.showerror("Permission Error", "Permission denied while trying to delete the file.")
    except Exception as e:
        messagebox.showerror("Error", f"An error occurred while deleting the file: {e}")

def read_diary():
    if os.path.exists("diary1.txt"):
        try:
            with open("diary1.txt", "rb") as file:
                encrypted_entries = file.readlines()

            decrypted_content = ""
            for encrypted_entry in encrypted_entries:
                try:
                    decrypted_content += cipher_suite.decrypt(encrypted_entry.strip()).decode() + "\n"
                except Exception as e:
                    messagebox.showerror("Decryption Error", f"Error decrypting entry: {e}")
                    continue

            read_window = Toplevel(screen)
            read_window.title("View Diary")
            read_window.geometry("1280x720+150+70")
            read_window.configure(bg="#d7dae2")
            read_window.resizable(False, False)

            diary_label = Label(read_window, text="Your Encrypted Diary Entries", font=("arial", 30, 'bold'), bg="#d7dae2")
            diary_label.pack(pady=20)

            diary_text = Text(read_window, font=("arial", 20), width=80, height=20)
            diary_text.insert(END, decrypted_content)
            diary_text.pack(pady=20)

        except Exception as e:
            messagebox.showerror("Error", f"An unexpected error occurred: {e}")
    else:
        messagebox.showwarning("No Entries", "No diary entries found.")

def open_diary():
    diary_window = Toplevel(screen)
    diary_window.title("Daily Diary")
    diary_window.geometry("1280x720+150+70")
    diary_window.configure(bg="#d7dae2")
    diary_window.resizable(False, False)

    diary_label = Label(diary_window, text="Write Your Daily Diary", font=("arial", 30, 'bold'), bg="#d7dae2")
    diary_label.pack(pady=20)

    diary_text = Text(diary_window, font=("arial", 20), width=80, height=15)
    diary_text.pack(pady=20)

    def save_diary():
        diary_content = diary_text.get("1.0", END).strip()
        if diary_content:
            current_time = datetime.now().strftime("%d-%m-%Y %H:%M:%S")
            entry = f"Entry Date and Time: {current_time}\n\n{diary_content}\n\n{'-'*40}\n\n"

            encrypted_entry = cipher_suite.encrypt(entry.encode())

            try:
                if os.path.exists("diary1.txt"):
                    os.chmod("diary1.txt", 0o666)
                else:
                    open("diary1.txt", "wb").close()
                with open("diary1.txt", "ab") as file:
                    file.write(encrypted_entry + b"\n")
                os.chmod("diary1.txt", 0o444)
                messagebox.showinfo("Saved", "Your diary entry has been saved and encrypted.")
            except PermissionError as e:
                messagebox.showerror("Permission Error", f"Permission error: {e}")
            except Exception as e:
                messagebox.showerror("Error", f"An unexpected error occurred: {e}")

            diary_text.delete("1.0", END)
        else:
            messagebox.showwarning("Empty", "Diary entry is empty.")

    Button(diary_window, text="Save Diary", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=save_diary).place(x=400, y=620)
    Button(diary_window, text="Delete Diary File", height="2", width=23, bg="#ff0000", fg="white", bd=0, command=delete_diary_file).place(x=600, y=620)
    Button(diary_window, text="Read Diary", height="2", width=23, bg="#ff8c00", fg="white", bd=0, command=read_diary).place(x=800, y=620)

def login():
    global STATIC_KEY, cipher_suite
    username = un.get()
    password = pw.get()

    user = get_user(username)

    if user:
        if user['password'] == password:
            STATIC_KEY = user['keyvalue'].encode() 
            cipher_suite = Fernet(STATIC_KEY)
            open_diary()
        else:
            messagebox.showerror("Invalid", "Invalid password")
    else:
        messagebox.showerror("Invalid", "Invalid username")

def main_screen():
    global screen
    global un
    global pw

    screen = Tk()
    screen.geometry("1280x720+150+80")
    screen.configure(bg="#d7dae2")

    img = Image.open("p1.png")
    i_i = ImageTk.PhotoImage(img)
    screen.iconphoto(False, i_i)
    screen.title("Login System")

    lt = Label(text="Login System", font=("arial", 50, 'bold'), fg="black", bg="#d7dae2")
    lt.pack(pady=50)

    bc = Frame(screen, bg="black", width=800, height=400)
    bc.pack(pady=20)

    mf = Frame(bc, bg="#d7dae2", width=800, height=400)
    mf.pack(padx=20, pady=20)

    Label(mf, text="Username", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=50)
    Label(mf, text="Password", font=("arial", 30, 'bold'), bg="#d7dae2").place(x=100, y=150)
    un = StringVar()
    pw = StringVar()

    eu = Entry(mf, textvariable=un, width=12, bd=2, font=("arial", 30))
    eu.place(x=400, y=50)
    ep = Entry(mf, textvariable=pw, width=12, bd=2, font=("arial", 30), show="*")
    ep.place(x=400, y=150)

    def reset():
        eu.delete(0, END)
        ep.delete(0, END)

    Button(mf, text="Login", height="2", width=23, bg="#ed3833", fg="white", bd=0, command=login).place(x=100, y=250)
    Button(mf, text="Reset", height="2", width=23, bg="#1089ff", fg="white", bd=0, command=reset).place(x=300, y=250)
    Button(mf, text="Exit", height="2", width=23, bg="#00bd56", fg="white", bd=0, command=screen.destroy).place(x=500, y=250)

    screen.mainloop()

main_screen()
#from cryptography.fernet import Fernet

# Generate and print the key
#key = Fernet.generate_key()
#print(key.decode())  # Print the key as a string to copy

# %%
git add login.ipynb
git commit -m "Final version, no modifications allowed"
# Out:
#   Cell In[8], line 1
#     git add login.ipynb
#         ^
# SyntaxError: invalid syntax
